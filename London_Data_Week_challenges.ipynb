# %% [markdown]
# # **London Data Week at Goodenough College**

# %% [markdown]
# ## Trees in Camden Dataset

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# ---------------------------------------------------------------------------
# MessageError                              Traceback (most recent call last)
# <ipython-input-1-d5df0069828e> in <cell line: 2>()
#       1 from google.colab import drive
# ----> 2 drive.mount('/content/drive')
#
# /usr/local/lib/python3.10/dist-packages/google/colab/drive.py in mount(mountpoint, force_remount, timeout_ms, readonly)
#      98 def mount(mountpoint, force_remount=False, timeout_ms=120000, readonly=False):
#      99   """Mount your Google Drive at the specified mountpoint path."""
# --> 100   return _mount(
#     101       mountpoint,
#     102       force_remount=force_remount,
#
# /usr/local/lib/python3.10/dist-packages/google/colab/drive.py in _mount(mountpoint, force_remount, timeout_ms, ephemeral, readonly)
#     131   )
#     132   if ephemeral:
# --> 133     _message.blocking_request(
#     134         'request_auth',
#     135         request={'authType': 'dfs_ephemeral'},
#
# ...

# %%
import pandas as pd

# Path to the CSV file
csv_file_path = '/content/drive/MyDrive/London_Data_Week_GC/trees_in_camden.csv'

# Load the data
df = pd.read_csv(csv_file_path)

# Display the first few rows
df.head()

# %% [markdown]
# Can you find are areas where there is a lack of tree coverage?

# %% [markdown]
# Can you map out the tree density on a London map?

# %% [markdown]
# ##Camden Housing Stock Prices

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd

# Path to the CSV file
csv_file_path = '/content/drive/MyDrive/London_Data_Week_GC/Camden_Housing_Stock_20240704.csv'

# Load the data
df = pd.read_csv(csv_file_path)

# Display the first few rows
df.head()
# Out:
# /usr/local/lib/python3.10/dist-packages/google/colab/_dataframe_summarizer.py:88: UserWarning: Parsing dates in %d/%m/%Y format when dayfirst=False (the default) was specified. Pass `dayfirst=True` or specify a format to silence this warning.
#   cast_date_col = pd.to_datetime(column, errors="coerce")
#    Property Reference Property Type Property Subtype  Bedroom Count Leased  \
# 0             40812.0          Flat              NaN            1.0     No
# 1             24029.0          Flat              NaN            0.0     No
# 2             35621.0          Flat              NaN            2.0     No
# 3             35732.0          Flat              NaN            3.0     No
# 4             40883.0          Flat              NaN            2.0     No
#
#   Lease Start Date District Name Estate Name           Ward Name  Easting  \
# 0              NaN  KENTISH TOWN           -  Kentish Town South      NaN
# ...

# %% [markdown]
# Can you find what borough has the most expensive properties?

# %% [markdown]
# Can you visualize the changing housing prices?
#
# Can you visualze any trends?

# %% [markdown]
# ##Camden Council Spending

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd

# Path to the CSV file
csv_file_path = '/content/drive/MyDrive/London_Data_Week_GC/camden_council_over_500_finances.csv'

# Load the data
df = pd.read_csv(csv_file_path)

# Display the first few rows
df.head()
# Out:
# /usr/local/lib/python3.10/dist-packages/google/colab/_dataframe_summarizer.py:88: UserWarning: Parsing dates in %d/%m/%Y format when dayfirst=False (the default) was specified. Pass `dayfirst=True` or specify a format to silence this warning.
#   cast_date_col = pd.to_datetime(column, errors="coerce")
#    Property Reference Property Type Property Subtype  Bedroom Count Leased  \
# 0             40812.0          Flat              NaN            1.0     No
# 1             24029.0          Flat              NaN            0.0     No
# 2             35621.0          Flat              NaN            2.0     No
# 3             35732.0          Flat              NaN            3.0     No
# 4             40883.0          Flat              NaN            2.0     No
#
#   Lease Start Date District Name Estate Name           Ward Name  Easting  \
# 0              NaN  KENTISH TOWN           -  Kentish Town South      NaN
# ...
